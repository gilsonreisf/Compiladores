# %%
from parser_2 import Parser2


def main():
  parser = Parser2()
  parser.PARSER()
  

if __name__ == "__main__":
  main()
# Out:
# --------------------------------------------------
# Token:  {'classe': 'inicio', 'lexema': 'inicio', 'tipo': 'inicio'}
# Pilha:  [0]
# SHIFT:  s2
# --------------------------------------------------
# Token:  {'classe': 'varinicio', 'lexema': 'varinicio', 'tipo': 'varinicio'}
# Pilha:  [0, 2]
# SHIFT:  s4
# --------------------------------------------------
# Token:  {'classe': 'literal', 'lexema': 'literal', 'tipo': 'literal'}
# Pilha:  [0, 2, 4]
# SHIFT:  s21
# --------------------------------------------------
# Token:  {'classe': 'id', 'lexema': 'A', 'tipo': 'NULO'}
# Pilha:  [0, 2, 4, 21]
# REDUCE:  R11
# Topo da pilha:  4
# Produção:  TIPO -> literal
# --------------------------------------------------
# Token:  {'classe': 'id', 'lexema': 'A', 'tipo': 'NULO'}
# Pilha:  [0, 2, 4, 18]
# SHIFT:  s40
# --------------------------------------------------
# Token:  {'classe': 'varfim', 'lexema': 'varfim', 'tipo': 'varfim'}
# Pilha:  [0, 2, 4, 18, 40]
# Phrase Recovery Mode
# ...

# %%
import pandas as pd

df_action = pd.read_csv('./tabelas/action.csv')

df_action
# Out:
#     estado inicio varinicio varfim pt_v   id  vir inteiro real literal  ...  \
# 0        0     s2        e0     e0   e0   e0   e0      e0   e0      e0  ...
# 1        1     e1        e1     e1   e1   e1   e1      e1   e1      e1  ...
# 2        2     e2        s4     e2   e2   e2   e2      e2   e2      e2  ...
# 3        3     e3        e3     e3   e3  s10   e3      e3   e3      e3  ...
# 4        4     e4        e4    s17   e4   e4   e4     s19  s20     s21  ...
# ..     ...    ...       ...    ...  ...  ...  ...     ...  ...     ...  ...
# 57      57    e57       e57    e57   R7  e57  e57     e57  e57     e57  ...
# 58      58    e58       e58    e58  e58  R26  e58     e58  e58     e58  ...
# 59      59    e59       e59    e59  e59  e59  e59     e59  e59     e59  ...
# 60      60    e60       e60    e60  e60  s45  e60     e60  e60     e60  ...
# 61      61    e61       e61    e61  R20  e61  e61     e61  e61     e61  ...
#
#     num   se ab_p fc_p  opr  opa entao fimse  fim  eof
# ...

# %%
from recuperacao_de_erro import *
import json


with open("tokens.json", "r") as f:
  listaDeTokens = json.load(f)

# phraseRecovery(40, 4, listaDeTokens)

listaDeTokens
# Out:
# [{'classe': 'inicio', 'lexema': 'inicio', 'tipo': 'inicio'},
#  {'classe': 'varinicio', 'lexema': 'varinicio', 'tipo': 'varinicio'},
#  {'classe': 'literal', 'lexema': 'literal', 'tipo': 'literal'},
#  {'classe': 'id', 'lexema': 'A', 'tipo': 'NULO'},
#  {'classe': 'varfim', 'lexema': 'varfim', 'tipo': 'varfim'},
#  {'classe': 'PT_V', 'lexema': ';', 'tipo': 'NULO'},
#  {'classe': 'PT_V', 'lexema': ';', 'tipo': 'NULO'},
#  {'classe': 'fim', 'lexema': 'fim', 'tipo': 'fim'},
#  {'classe': 'EOF', 'lexema': 'EOF', 'tipo': None}]
